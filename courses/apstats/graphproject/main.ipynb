# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# importing dataset
data = pd.read_csv('data/responses_cleaned.csv')
data.head()
# Out:
#            Timestamp      Email Address    Period Phone Preference  \
# 0  8/10/2023 9:05:59  s210349@scusd.net  Period 1           iPhone
# 1  8/10/2023 9:08:42  s167747@scusd.net  Period 1           iPhone
# 2  8/10/2023 9:20:23  s212982@scusd.net  Period 1           iPhone
# 3  8/10/2023 9:26:46  s187688@scusd.net  Period 1           iPhone
# 4  8/10/2023 9:26:59  s171443@scusd.net  Period 1           iPhone
#
#    Hours of Exercise English Class  Minutes to Get Ready Pairs of Shoes  \
# 0                  3    English 10                  20.0             14
# 1                  2    English 9H                  30.0              4
# 2                  1    English 9H                  60.0              3
# 3                  2     English 9                  10.0              3
# 4                  3     English 9                  30.0              4
#
#   Favorite Social Media Favorite Color  ... Hours of Sleep  Height in Inches  \
# ...

# %%
data.boxplot(by='Favorite Color', column='Minutes to Get Ready',vert=0)
plt.title('Student Time to Get Ready by Favorite Color')
plt.suptitle('')
plt.xlabel('Time to Get Ready (Min)')
plt.show()

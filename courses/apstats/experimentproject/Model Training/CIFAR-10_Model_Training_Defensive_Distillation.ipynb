# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

# Display the version
print(tf.__version__)

# import and mount Drive
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# 2.13.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# get path to folder file is in
file_path = '/content/gdrive/MyDrive/apstats-experimentproject'
print(file_path)
# Out:
# Requirement already satisfied: kora in /usr/local/lib/python3.10/dist-packages (0.9.20)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from kora) (7.34.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from kora) (1.5.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->kora) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->kora) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->kora) (0.2.6)
# /content/gdrive/My Drive/Personal Projects/Pioneer Academics Research/code/CIFAR-10

# %%
# Download the data from tf, unless it's already here.
if not os.path.exists(file_path+'/data/clean'):
  os.mkdir(file_path+'/data/clean')
  (X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
  np.save(file_path+'/data/clean/X_train.npy',X_train)
  np.save(file_path+'/data/clean/y_train.npy',y_train)
  np.save(file_path+'/data/clean/X_test.npy',X_test)
  np.save(file_path+'/data/clean/y_test.npy',y_test)
else:
  X_train = np.load(file_path+'/data/clean/X_train.npy')
  y_train = np.load(file_path+'/data/clean/y_train.npy')
  X_test = np.load(file_path+'/data/clean/X_test.npy')
  y_test = np.load(file_path+'/data/clean/y_test.npy')

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)
# X_test shape (10000, 32, 32, 3)
# y_test shape (10000, 1)

# %%
# Converting to float32 and reducing pixel values
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Code to train a model
def train(params=[64, 64, 128, 128, 256, 256], labels=y_train, file_name=(file_path + '/models/defensive_distillation.keras'), temperature = 20, num_epochs = 50, lr = 0.0003, drop = 0.2, reg = 1e-4, batch_size=32):
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(params[0], (3, 3), input_shape=X_train.shape[1:], padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Conv2D(params[1], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[2], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[3], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(params[4], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(params[5], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(10, kernel_regularizer=tf.keras.regularizers.L2(reg)))

    def temperature_cross_entropy(gt, pred):
      loss = tf.nn.softmax_cross_entropy_with_logits(labels=gt, logits=pred/temperature)
      return loss

    model.compile(loss=temperature_cross_entropy,
                  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  metrics=['accuracy'])

    model.summary()

    model.fit(X_train, labels,
              batch_size=batch_size,
              validation_split=0.1,
              epochs=num_epochs,
              shuffle=True,
              verbose=1)

    if file_name != None:
        model.save(file_name)

    return model

# %%
# Create the teacher model
model = train(file_name=(file_path + '/models/distillation_teacher.keras'))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 459850 (1.75 MB)
# Trainable params: 459850 (1.75 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 11s 6ms/step - loss: 1.9132 - accuracy: 0.2907 - val_loss: 1.6498 - val_accuracy: 0.4078
# Epoch 2/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.6006 - accuracy: 0.4280 - val_loss: 1.4580 - val_accuracy: 0.4874
# Epoch 3/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4589 - accuracy: 0.4869 - val_loss: 1.3765 - val_accuracy: 0.5274
# Epoch 4/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3656 - accuracy: 0.5272 - val_loss: 1.2711 - val_accuracy: 0.5688
# Epoch 5/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.2769 - accuracy: 0.5612 - val_loss: 1.1639 - val_accuracy: 0.6100
# Epoch 6/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2118 - accuracy: 0.5888 - val_loss: 1.1184 - val_accuracy: 0.6300
# Epoch 7/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1505 - accuracy: 0.6165 - val_loss: 1.0372 - val_accuracy: 0.6636
# Epoch 8/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0982 - accuracy: 0.6400 - val_loss: 0.9769 - val_accuracy: 0.6900
# Epoch 9/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.0521 - accuracy: 0.6602 - val_loss: 0.9616 - val_accuracy: 0.6956
# Epoch 10/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0132 - accuracy: 0.6764 - val_loss: 0.9050 - val_accuracy: 0.7182
# Epoch 11/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9780 - accuracy: 0.6921 - val_loss: 0.9320 - val_accuracy: 0.7164
# Epoch 12/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9568 - accuracy: 0.7009 - val_loss: 0.8641 - val_accuracy: 0.7428
# Epoch 13/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9210 - accuracy: 0.7164 - val_loss: 0.8454 - val_accuracy: 0.7508
# Epoch 14/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8932 - accuracy: 0.7288 - val_loss: 0.8365 - val_accuracy: 0.7504
# Epoch 15/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8708 - accuracy: 0.7376 - val_loss: 0.8214 - val_accuracy: 0.7634
# Epoch 16/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.8495 - accuracy: 0.7454 - val_loss: 0.8021 - val_accuracy: 0.7680
# Epoch 17/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.8304 - accuracy: 0.7558 - val_loss: 0.7708 - val_accuracy: 0.7842
# Epoch 18/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.8163 - accuracy: 0.7593 - val_loss: 0.7821 - val_accuracy: 0.7770
# Epoch 19/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7915 - accuracy: 0.7695 - val_loss: 0.7801 - val_accuracy: 0.7788
# Epoch 20/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7823 - accuracy: 0.7771 - val_loss: 0.7699 - val_accuracy: 0.7856
# Epoch 21/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7681 - accuracy: 0.7828 - val_loss: 0.7536 - val_accuracy: 0.7916
# Epoch 22/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7503 - accuracy: 0.7880 - val_loss: 0.7499 - val_accuracy: 0.7948
# Epoch 23/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7393 - accuracy: 0.7931 - val_loss: 0.7362 - val_accuracy: 0.7980
# Epoch 24/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7294 - accuracy: 0.7966 - val_loss: 0.7274 - val_accuracy: 0.8072
# Epoch 25/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7218 - accuracy: 0.7993 - val_loss: 0.7528 - val_accuracy: 0.7960
# Epoch 26/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.7102 - accuracy: 0.8069 - val_loss: 0.7414 - val_accuracy: 0.7992
# Epoch 27/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6929 - accuracy: 0.8130 - val_loss: 0.7522 - val_accuracy: 0.7946
# Epoch 28/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6882 - accuracy: 0.8141 - val_loss: 0.7291 - val_accuracy: 0.8054
# Epoch 29/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6812 - accuracy: 0.8182 - val_loss: 0.7095 - val_accuracy: 0.8116
# Epoch 30/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6755 - accuracy: 0.8216 - val_loss: 0.7277 - val_accuracy: 0.8062
# Epoch 31/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6634 - accuracy: 0.8279 - val_loss: 0.7327 - val_accuracy: 0.8062
# Epoch 32/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6590 - accuracy: 0.8278 - val_loss: 0.7205 - val_accuracy: 0.8094
# Epoch 33/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6581 - accuracy: 0.8300 - val_loss: 0.7297 - val_accuracy: 0.8116
# Epoch 34/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.6474 - accuracy: 0.8341 - val_loss: 0.7184 - val_accuracy: 0.8134
# Epoch 35/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6388 - accuracy: 0.8366 - val_loss: 0.7296 - val_accuracy: 0.8120
# Epoch 36/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6324 - accuracy: 0.8382 - val_loss: 0.7397 - val_accuracy: 0.8040
# Epoch 37/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6329 - accuracy: 0.8392 - val_loss: 0.7067 - val_accuracy: 0.8190
# Epoch 38/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6228 - accuracy: 0.8454 - val_loss: 0.7261 - val_accuracy: 0.8150
# Epoch 39/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6191 - accuracy: 0.8472 - val_loss: 0.7240 - val_accuracy: 0.8176
# Epoch 40/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6172 - accuracy: 0.8480 - val_loss: 0.7312 - val_accuracy: 0.8194
# Epoch 41/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6162 - accuracy: 0.8472 - val_loss: 0.7213 - val_accuracy: 0.8166
# Epoch 42/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6095 - accuracy: 0.8501 - val_loss: 0.7148 - val_accuracy: 0.8198
# Epoch 43/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.6063 - accuracy: 0.8525 - val_loss: 0.7272 - val_accuracy: 0.8140
# Epoch 44/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5999 - accuracy: 0.8556 - val_loss: 0.7164 - val_accuracy: 0.8228
# Epoch 45/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5975 - accuracy: 0.8576 - val_loss: 0.7094 - val_accuracy: 0.8260
# Epoch 46/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5939 - accuracy: 0.8581 - val_loss: 0.7406 - val_accuracy: 0.8148
# Epoch 47/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5950 - accuracy: 0.8574 - val_loss: 0.7387 - val_accuracy: 0.8148
# Epoch 48/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5881 - accuracy: 0.8612 - val_loss: 0.7362 - val_accuracy: 0.8126
# Epoch 49/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5837 - accuracy: 0.8628 - val_loss: 0.7232 - val_accuracy: 0.8230
# Epoch 50/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5818 - accuracy: 0.8638 - val_loss: 0.7262 - val_accuracy: 0.8226

# %%
# Evaluate efficacy of teacher model
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7435 - accuracy: 0.8124
# [0.7435294985771179, 0.8123999834060669]

# %%
# Create 'soft labels' for Defensive Distillation
y_soft_train = model.predict(X_train, batch_size=32)
y_soft_train = tf.nn.softmax(y_soft_train/20)
print(y_soft_train.shape)
# Out:
# 1563/1563 [==============================] - 3s 2ms/step
# (50000, 10)

# %%
# Create the student (distilled) model
distilled_model = train(labels=y_soft_train, file_name=(file_path + '/models/distillation_student.keras'))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 32, 32, 64)        1792
#
#  max_pooling2d_32 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_48 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_33 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_49 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_34 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  dropout_50 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_35 (MaxPooli  (None, 2, 2, 128)         0
#  ng2D)
#
#  dropout_51 (Dropout)        (None, 2, 2, 128)         0
#
#  flatten_8 (Flatten)         (None, 512)               0
#
#  dense_24 (Dense)            (None, 256)               131328
#
#  dropout_52 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 256)               65792
#
#  dropout_53 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 459850 (1.75 MB)
# Trainable params: 459850 (1.75 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 11s 6ms/step - loss: 1.9204 - accuracy: 0.3081 - val_loss: 1.6308 - val_accuracy: 0.4450
# Epoch 2/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.5978 - accuracy: 0.4444 - val_loss: 1.4317 - val_accuracy: 0.5280
# Epoch 3/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.4386 - accuracy: 0.5076 - val_loss: 1.2821 - val_accuracy: 0.5942
# Epoch 4/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.3412 - accuracy: 0.5527 - val_loss: 1.2227 - val_accuracy: 0.6130
# Epoch 5/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.2600 - accuracy: 0.5866 - val_loss: 1.1480 - val_accuracy: 0.6498
# Epoch 6/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.1808 - accuracy: 0.6221 - val_loss: 1.0502 - val_accuracy: 0.6906
# Epoch 7/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.1262 - accuracy: 0.6483 - val_loss: 0.9671 - val_accuracy: 0.7442
# Epoch 8/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.0755 - accuracy: 0.6696 - val_loss: 0.9349 - val_accuracy: 0.7530
# Epoch 9/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.0393 - accuracy: 0.6866 - val_loss: 0.9084 - val_accuracy: 0.7710
# Epoch 10/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.0054 - accuracy: 0.7045 - val_loss: 0.8595 - val_accuracy: 0.7914
# Epoch 11/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.9746 - accuracy: 0.7191 - val_loss: 0.8650 - val_accuracy: 0.7950
# Epoch 12/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.9431 - accuracy: 0.7351 - val_loss: 0.8316 - val_accuracy: 0.8122
# Epoch 13/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.9183 - accuracy: 0.7461 - val_loss: 0.8276 - val_accuracy: 0.8160
# Epoch 14/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.8980 - accuracy: 0.7573 - val_loss: 0.8102 - val_accuracy: 0.8296
# Epoch 15/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8796 - accuracy: 0.7660 - val_loss: 0.7938 - val_accuracy: 0.8286
# Epoch 16/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8622 - accuracy: 0.7730 - val_loss: 0.7906 - val_accuracy: 0.8338
# Epoch 17/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8458 - accuracy: 0.7832 - val_loss: 0.7661 - val_accuracy: 0.8480
# Epoch 18/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8278 - accuracy: 0.7922 - val_loss: 0.7851 - val_accuracy: 0.8330
# Epoch 19/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8177 - accuracy: 0.7966 - val_loss: 0.8046 - val_accuracy: 0.8302
# Epoch 20/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8128 - accuracy: 0.8000 - val_loss: 0.7582 - val_accuracy: 0.8544
# Epoch 21/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8016 - accuracy: 0.8067 - val_loss: 0.7701 - val_accuracy: 0.8516
# Epoch 22/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7917 - accuracy: 0.8110 - val_loss: 0.7549 - val_accuracy: 0.8548
# Epoch 23/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7851 - accuracy: 0.8143 - val_loss: 0.7376 - val_accuracy: 0.8708
# Epoch 24/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7816 - accuracy: 0.8170 - val_loss: 0.7468 - val_accuracy: 0.8586
# Epoch 25/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7777 - accuracy: 0.8207 - val_loss: 0.7412 - val_accuracy: 0.8652
# Epoch 26/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7668 - accuracy: 0.8254 - val_loss: 0.7387 - val_accuracy: 0.8644
# Epoch 27/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7638 - accuracy: 0.8292 - val_loss: 0.7571 - val_accuracy: 0.8576
# Epoch 28/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7584 - accuracy: 0.8311 - val_loss: 0.7312 - val_accuracy: 0.8704
# Epoch 29/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7534 - accuracy: 0.8351 - val_loss: 0.7352 - val_accuracy: 0.8652
# Epoch 30/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7474 - accuracy: 0.8351 - val_loss: 0.7413 - val_accuracy: 0.8696
# Epoch 31/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7497 - accuracy: 0.8369 - val_loss: 0.7450 - val_accuracy: 0.8656
# Epoch 32/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7446 - accuracy: 0.8381 - val_loss: 0.7488 - val_accuracy: 0.8638
# Epoch 33/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7384 - accuracy: 0.8439 - val_loss: 0.7401 - val_accuracy: 0.8698
# Epoch 34/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7361 - accuracy: 0.8445 - val_loss: 0.7344 - val_accuracy: 0.8694
# Epoch 35/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7338 - accuracy: 0.8465 - val_loss: 0.7366 - val_accuracy: 0.8708
# Epoch 36/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7319 - accuracy: 0.8459 - val_loss: 0.7695 - val_accuracy: 0.8528
# Epoch 37/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7287 - accuracy: 0.8467 - val_loss: 0.7270 - val_accuracy: 0.8760
# Epoch 38/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7280 - accuracy: 0.8487 - val_loss: 0.7341 - val_accuracy: 0.8682
# Epoch 39/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7248 - accuracy: 0.8507 - val_loss: 0.7378 - val_accuracy: 0.8706
# Epoch 40/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7211 - accuracy: 0.8544 - val_loss: 0.7395 - val_accuracy: 0.8694
# Epoch 41/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7196 - accuracy: 0.8536 - val_loss: 0.7370 - val_accuracy: 0.8742
# Epoch 42/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7181 - accuracy: 0.8539 - val_loss: 0.7386 - val_accuracy: 0.8700
# Epoch 43/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7155 - accuracy: 0.8556 - val_loss: 0.7332 - val_accuracy: 0.8748
# Epoch 44/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7137 - accuracy: 0.8586 - val_loss: 0.7276 - val_accuracy: 0.8744
# Epoch 45/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7131 - accuracy: 0.8598 - val_loss: 0.7353 - val_accuracy: 0.8680
# Epoch 46/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7103 - accuracy: 0.8602 - val_loss: 0.7362 - val_accuracy: 0.8772
# Epoch 47/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7106 - accuracy: 0.8611 - val_loss: 0.7304 - val_accuracy: 0.8736
# Epoch 48/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7065 - accuracy: 0.8631 - val_loss: 0.7465 - val_accuracy: 0.8638
# Epoch 49/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.7108 - accuracy: 0.8598 - val_loss: 0.7249 - val_accuracy: 0.8732
# Epoch 50/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7042 - accuracy: 0.8633 - val_loss: 0.7309 - val_accuracy: 0.8706

# %%
# Evaluate efficacy of student (distilled) model on a set the model has never seen
distilled_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7017 - accuracy: 0.8053
# [0.7017470002174377, 0.8052999973297119]
